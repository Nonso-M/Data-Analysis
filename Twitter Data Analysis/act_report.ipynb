# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# ### Wrangle & Analyze WeRateDogs Data
# ### Analysis & Insights Report
# The purpose of this project is to put into practice what I’ve learned in Data
# wrangling  data  course  which  is  part  of  Udacity  Data  Analysis  Nanodegree
# program. The dataset that I will be wrangling is the tweet archive of Twitter user @dog_rates, also known as WeRateDogs.
# WeRateDogs  is  a  Twitter  account  that  gives  ratings  to  users'  dogs  along  with  a
# humorous anecdote about the pet.
# These are some of the insights gained from the analysis done on the provided data
# after data cleansing, wrangling, and some Explanatory Data Analysis (EDA) were
# done.

# %% [markdown]
# ### Most popular dog name
# THis was gotten using the command below
# `df_dog.name.value_counts().reset_index().loc[1:, :].head(10)`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Most popular dog breed he rated
#
# This was gotten using the command below
# ```python
# df_dog_type= df_model.query('p1_dog == True').\
#                     groupby('p1')\
#                     ['tweet_id'].count().sort_values(ascending= False).\
#                     reset_index().head(10)
#
# df_dog_type
#
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### What dog breed has the highest ratings
#
# This was gotten using the the following command
# ```python
# top_dog_score = df_merge.query('p1_dog== True').\
#                 groupby('p1')['rating_numerator'].\
#                 agg(['mean', 'count'])\
#                 .sort_values(['mean', 'count'], ascending= False)\
#                 .reset_index().head(10)
#
# top_dog_score.rename(columns= {'p1': 'dog_breed'}, inplace = True)
#
# top_dog_score
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Visualization
# ### What breed does the audience like the most
#
# This plot was gotten using the following command
# ```python
# df_liked.query('p1_dog== True').\
#                 groupby('p1')['favorite_count'].mean()\
#                 .sort_values(ascending=False).\
#                 head(10).plot(kind= 'barh', figsize=(10,8));
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
jupyter nbconvert --to html wrangle_act.ipynb
